# %% [markdown]
# # Ejercicio 1

# %%
# Para realizar los ejercicios usar el archivo
# csvAutomobile_data.csv.
# A partir del conjunto de datos dado, imprime las
# cinco primeras y últimas filas.

import pandas as pd

df = pd.read_csv("../archivos/Modulo5_Automobile_data-221102-123259.csv")

print(df.head()) #Head solo mustra los 5 primeros
print()
print(df.tail()) #Tail solo muestra los 5 ultimos (Pero se les puede especificar el número de filas a mostrar)
# Out:
#    Unnamed: 0  index      company   body-style  wheel-base  length  \
# 0           0      0  alfa-romero            ?        88.6   168.8
# 1           1      1  alfa-romero  convertible        88.6   168.8
# 2           2      2  alfa-romero    hatchback        94.5   171.2
# 3           3      3         audi        sedan        99.8   176.6
# 4           4      4         audi            ?        99.4   176.6
#
#   engine-type num-of-cylinders horsepower  average-mileage    price
# 0        dohc             four        111             21.0  13495.0
# 1        dohc             four        111             21.0  16500.0
# 2        ohcv              six        154             19.0  16500.0
# 3         ohc             four        102             24.0  13950.0
# 4         ohc             five        115             18.0  17450.0
#
#     Unnamed: 0  index     company body-style  wheel-base  length engine-type  \
# ...

# %% [markdown]
# # Ejercicio 2

# %%
# Limpia el conjunto de datos y actualiza el archivo
# CSV. Reemplaza todos los valores de las
# columnas que contengan ?, n.a, o NaN.

import pandas as pd
import numpy as np

df = pd.read_csv("../archivos/Modulo5_Automobile_data-221102-123259.csv")

# Reemplazar valores inválidos por NaN real
df = df.replace(["?", "n.a", "NaN"], "desconocido")
df = df.fillna("desconocido")

if df.isna().sum().sum() == 0:
    # Guardar el archivo limpio
    df.to_csv("../archivos/Modulo5_Automobile_data_limpio.csv", index=False)
    print("Archivo limpiado y actualizado correctamente.")
else:
    print("Aún hay valores nulos en el archivo.")
# Out:
# Archivo limpiado y actualizado correctamente.

# %% [markdown]
# ## Ejercicio 3

# %%
# Encuentra el nombre de la empresa del coche
# más caro. Imprime el nombre de la empresa del
# coche más caro y su precio.


import pandas as pd


df = pd.read_csv("../archivos/Modulo5_Automobile_data_arreglado.csv")

max_price = df["price"].max()
# print(max_price)
car = df[df["price"] == max_price]
# print(car)
# print()

print(f"La empresa del coche más caro es: {car['company'].iloc[0]} y su precio es: {max_price}")


print()
print()
print()
caro = df.loc[df["price"].idxmax()]

print("Empresa:", caro["company"])
print("Precio:", caro["price"])
# Out:
# La empresa del coche más caro es: mercedes-benz y su precio es: 45400.0
#
#
#
# Empresa: mercedes-benz
# Precio: 45400.0

# %% [markdown]
# ## Ejercicio 4

# %%
# Imprime todos los datos de los coches Toyota.

import pandas as pd

df = pd.read_csv("../archivos/Modulo5_Automobile_data_arreglado.csv")
coche_toyota = df[df["company"] == "toyota"]
print(coche_toyota)
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 48          48     66  toyota  hatchback        95.7   158.7         ohc
# 49          49     67  toyota  hatchback        95.7   158.7         ohc
# 50          50     68  toyota  hatchback        95.7   158.7         ohc
# 51          51     69  toyota      wagon        95.7   169.7         ohc
# 52          52     70  toyota      wagon        95.7   169.7         ohc
# 53          53     71  toyota      wagon        95.7   169.7         ohc
# 54          54     79  toyota      wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 48             four          62               35   5348.0
# 49             four          62               31   6338.0
# 50             four          62               31   6488.0
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# ...

# %% [markdown]
# ## Ejercicio 5

# %%
# Cuenta el total de coches por empresa.

import pandas as pd

df = pd.read_csv("../archivos/Modulo5_Automobile_data-221102-123259.csv")

# los agrupo por compañia y luego .size() calcula la cantidad de filas que tiene cada grupo
coches_por_empresa = df.groupby("company").size()
print(coches_por_empresa)

print()
# selecciono la columna de compañia y .value_counts() cuenta los valores que se repiten en la columna y los organiza de mayor a menor
coches_empresa = df['company'].value_counts()
print(coches_empresa)
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            3
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          3
# toyota           7
# volkswagen       4
# volvo            2
# dtype: int64
#
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %% [markdown]
# ## Ejercicio 6

# %%
# Encuentra el coche con el precio más alto de
# precio de cada empresa.

import pandas as pd

df = pd.read_csv("../archivos/Modulo5_Automobile_data-221102-123259.csv")

coche_mas_caro_por_empresa = df.loc[df.groupby("company")["price"].idxmax()]

print(coche_mas_caro_por_empresa)


# df.groupby('native-country')['capital-gain'].agg([len, min, max])
print()
coche_mas_caro = df.groupby("company")["price"].max()
print(coche_mas_caro)

print()
coche_mas_caro = df.groupby("company")["price"].agg("max")
print(coche_mas_caro)
# Out:
#     Unnamed: 0  index        company   body-style  wheel-base  length  \
# 1            1      1    alfa-romero  convertible        88.6   168.8
# 6            6      6           audi        wagon       105.8   192.7
# 11          11     14            bmw        sedan       103.5   193.8
# 15          15     18      chevrolet        sedan        94.5   158.8
# 16          16     19          dodge    hatchback        93.7   157.3
# 19          19     28          honda        sedan        96.5   175.4
# 21          21     30          isuzu        sedan        94.3   170.7
# 26          26     35         jaguar        sedan       102.0   191.7
# 31          31     43          mazda        sedan       104.9   175.0
# 35          35     47  mercedes-benz      hardtop       112.0   199.2
# 39          39     52     mitsubishi        sedan        96.3   172.4
# 44          44     57         nissan        sedan       100.4   184.6
# ...

# %% [markdown]
# ## Ejercicio 7

# %%
# Encuentra el kilometraje medio de cada empresa
# fabricante de automóviles.

import pandas as pd

df = pd.read_csv("../archivos/Modulo5_Automobile_data-221102-123259.csv")

#mean calcula la media
kilometraje_medio_empresa = df.groupby("company")["average-mileage"].mean()
print(kilometraje_medio_empresa)
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %% [markdown]
# ## Ejercicio 8

# %%
# Ordena todos los coches por la columna Precio.

import pandas as pd

df = pd.read_csv("../archivos/Modulo5_Automobile_data-221102-123259.csv")

# pd.set_option("display.max_rows", None)

df_sorted = df.sort_values("price", ascending=True)
print(df_sorted)

print()
df_sorted = df.sort_values("price", ascending=False)
print(df_sorted)
# Out:
#     Unnamed: 0  index        company body-style  wheel-base  length  \
# 13          13     16      chevrolet  hatchback        88.4   141.1
# 27          27     36          mazda  hatchback        93.1   159.1
# 48          48     66         toyota  hatchback        95.7   158.7
# 36          36     49     mitsubishi  hatchback        93.7   157.3
# 28          28     37          mazda  hatchback        93.1   159.1
# ..         ...    ...            ...        ...         ...     ...
# 11          11     14            bmw      sedan       103.5   193.8
# 35          35     47  mercedes-benz    hardtop       112.0   199.2
# 22          22     31          isuzu      sedan        94.5   155.9
# 23          23     32          isuzu      sedan        94.5   155.9
# 47          47     63        porsche  hatchback        98.4   175.7
#
#    engine-type num-of-cylinders horsepower  average-mileage    price
# 13           l            three         48             47.0   5151.0
# ...

# %% [markdown]
# ## Ejercicio 9

# %%
# Concatena dos dataframes utilizando las
# siguientes condiciones:
# MUSK
# GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925, 71400]}
# japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi'], 'Price': [29995, 23600, 61500, 58
# 900]}

import pandas as pd

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925, 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi'], 'Price': [29995, 23600, 61500, 58900]}

df_GermanCars = pd.DataFrame(GermanCars)
df_japaneseCars = pd.DataFrame(japaneseCars)

#ignoreindex hace que el indice sea corrido en vez de reiniciarce por cada dataframe qie se concatene
df_concatenado = pd.concat([df_GermanCars, df_japaneseCars], ignore_index=True)
print(df_concatenado)
# Out:
#       Company   Price
# 0        Ford   23845
# 1    Mercedes  171995
# 2         BMV  135925
# 3        Audi   71400
# 4      Toyota   29995
# 5       Honda   23600
# 6      Nissan   61500
# 7  Mitsubishi   58900

# %% [markdown]
# ## Ejercicio 10

# %%
# Combina dos dataframe utilizando la siguiente
# condición. Crea dos dataframe utilizando los
# siguientes dos Dicts, fusiónalos y añade el
# segundo dataframe como una nueva columna al
# primer dataframe.

import pandas as pd

Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925, 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182, 160]}

df_Car_Price = pd.DataFrame(Car_Price)
df_car_Horsepower = pd.DataFrame(car_Horsepower)

df_combined = df_Car_Price.merge(df_car_Horsepower, on='Company')
print(df_combined)
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
